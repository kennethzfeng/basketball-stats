# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %% [markdown]
# ## Teams

# %%
teams = pd.read_csv("RawData/BasketballDB-20130121/basketball_teams.csv")
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1536 entries, 0 to 1535
# Data columns (total 60 columns):
# year           1536 non-null int64
# lgID           1536 non-null object
# tmID           1536 non-null object
# franchID       1536 non-null object
# confID         1064 non-null object
# divID          1498 non-null object
# rank           1536 non-null int64
# confRank       1536 non-null int64
# playoff        901 non-null object
# name           1536 non-null object
# o_fgm          1536 non-null int64
# o_fga          1536 non-null int64
# o_ftm          1536 non-null int64
# o_fta          1536 non-null int64
# o_3pm          1536 non-null int64
# o_3pa          1536 non-null int64
# o_oreb         1536 non-null int64
# o_dreb         1536 non-null int64
# o_reb          1536 non-null int64
# o_asts         1536 non-null int64
# o_pf           1536 non-null int64
# o_stl          1536 non-null int64
# o_to           1536 non-null int64
# ...

# %%
teams.head()
# Out:
#    year lgID tmID franchID confID divID  rank  confRank playoff  \
# 0  1946  NBA  BOS      BOS    NaN    ED     5         0     NaN
# 1  1946  NBA  CHS      CHS    NaN    WD     1         0       F
# 2  1946  NBA  CLR      CLR    NaN    WD     3         0      R1
# 3  1946  NBA  DTF      DTF    NaN    WD     4         0     NaN
# 4  1946  NBA  NYK      NYK    NaN    ED     3         0      SF
#
#                name  o_fgm  o_fga  o_ftm  o_fta  o_3pm  o_3pa  o_oreb  o_dreb  \
# 0    Boston Celtics   1397   5133    811   1375      0      0       0       0
# 1     Chicago Stags   1879   6309    939   1550      0      0       0       0
# 2  Cleveland Rebels   1674   5699    903   1428      0      0       0       0
# 3   Detroit Falcons   1437   5843    923   1494      0      0       0       0
# 4   New York Knicks   1465   5255    951   1438      0      0       0       0
#
#    o_reb  o_asts
# 0      0     470 ...
# 1      0     436 ...
# 2      0     494 ...
# 3      0     482 ...
# ...

# %% [markdown]
# ## Players

# %%
players = pd.read_csv("RawData/BasketballDB-20130121/basketball_players.csv")
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23751 entries, 0 to 23750
# Data columns (total 42 columns):
# playerID              23751 non-null object
# year                  23751 non-null int64
# stint                 23751 non-null int64
# tmID                  23751 non-null object
# lgID                  23751 non-null object
# GP                    23751 non-null int64
# GS                    23751 non-null int64
# minutes               23751 non-null int64
# points                23751 non-null int64
# oRebounds             23751 non-null int64
# dRebounds             23751 non-null int64
# rebounds              23751 non-null int64
# assists               23751 non-null int64
# steals                23751 non-null int64
# blocks                23751 non-null int64
# turnovers             23751 non-null int64
# PF                    23751 non-null int64
# fgAttempted           23751 non-null int64
# fgMade                23751 non-null int64
# ...

# %%
players.head()
# Out:
#     playerID  year  stint tmID lgID  GP  GS  minutes  points  oRebounds  \
# 0  abramjo01  1946      1  PIT  NBA  47   0        0     527          0
# 1  aubucch01  1946      1  DTF  NBA  30   0        0      65          0
# 2  bakerno01  1946      1  CHS  NBA   4   0        0       0          0
# 3  baltihe01  1946      1  STB  NBA  58   0        0     138          0
# 4   barrjo01  1946      1  STB  NBA  58   0        0     295          0
#
#    dRebounds  rebounds  assists  steals  blocks  turnovers   PF  fgAttempted  \
# 0          0         0       35       0       0          0  161          834
# 1          0         0       20       0       0          0   46           91
# 2          0         0        0       0       0          0    0            1
# 3          0         0       16       0       0          0   98          263
# 4          0         0       54       0       0          0  164          438
#
#    fgMade  ftAttempted
# 0     202          178 ...
# ...

# %% [markdown]
# ## abbrev

# %%
abbrev = pd.read_csv("RawData/BasketballDB-20130121/basketball_abbrev.csv")
abbrev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 39
# Data columns (total 3 columns):
# abbrev_type    40 non-null object
# code           40 non-null object
# full_name      40 non-null object
# dtypes: object(3)

# %%
abbrev.head()
# Out:
#   abbrev_type code           full_name
# 0       Round   DF     Division Finals
# 1  Conference   EC  Eastern Conference
# 2  Conference   WC  Western Conference
# 3    Division   AT   Atlantic Division
# 4    Division   ED    Eastern Division
#
# [5 rows x 3 columns]

# %% [markdown]
# ## coaches

# %%
coaches = pd.read_csv("RawData/BasketballDB-20130121/basketball_coaches.csv")
coaches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689 entries, 0 to 1688
# Data columns (total 9 columns):
# coachID        1689 non-null object
# year           1689 non-null int64
# tmID           1689 non-null object
# lgID           1689 non-null object
# stint          1689 non-null int64
# won            1680 non-null float64
# lost           1680 non-null float64
# post_wins      1649 non-null float64
# post_losses    1649 non-null float64
# dtypes: float64(4), int64(2), object(3)

# %%
coaches.head()
# Out:
#      coachID  year tmID  lgID  stint  won  lost  post_wins  post_losses
# 0  johnsne01  1961  PGR  ABL1      1   41    40          0            1
# 1  auerbre01  1946  WSC   NBA      1   49    11          2            4
# 2  birchpa01  1946  PIT   NBA      1   15    45          0            0
# 3  cliffro01  1946  CLR   NBA      2   13    10          1            2
# 4  cohalne01  1946  NYK   NBA      1   33    27          2            3
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Draft

# %%
drafts = pd.read_csv("RawData/BasketballDB-20130121/basketball_draft.csv")
drafts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9003 entries, 0 to 9002
# Data columns (total 11 columns):
# draftYear         9003 non-null int64
# draftRound        9003 non-null int64
# draftSelection    9003 non-null int64
# draftOverall      9003 non-null int64
# tmID              9003 non-null object
# firstName         9003 non-null object
# lastName          9003 non-null object
# suffixName        2 non-null object
# playerID          3814 non-null object
# draftFrom         8997 non-null object
# lgID              9003 non-null object
# dtypes: int64(4), object(7)

# %%
drafts.head()
# Out:
#    draftYear  draftRound  draftSelection  draftOverall tmID firstName  \
# 0       1967           0               0             0  ANA   Darrell
# 1       1967           0               0             0  ANA       Bob
# 2       1967           0               0             0  ANA       Bob
# 3       1967           0               0             0  ANA      Mike
# 4       1967           0               0             0  ANA       Tom
#
#   lastName suffixName   playerID       draftFrom lgID
# 0    Hardy        NaN  hardyda01          Baylor  ABA
# 1  Krulish        NaN        NaN         Pacific  ABA
# 2    Lewis        NaN  lewisbo01  North Carolina  ABA
# 3     Lynn        NaN   lynnmi01            UCLA  ABA
# 4  Workman        NaN  workmto01         Seattle  ABA
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Hall of Fame

# %%
hof = pd.read_csv("RawData/BasketballDB-20130121/basketball_hof.csv")
hof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 328 entries, 0 to 327
# Data columns (total 4 columns):
# year        328 non-null int64
# hofID       140 non-null object
# name        328 non-null object
# category    328 non-null object
# dtypes: int64(1), object(3)

# %%
hof.head()
# Out:
#    year      hofID               name     category
# 0  1959        NaN  Amos Alonzo Stagg  Contributor
# 1  1959        NaN      Charles Hyatt       Player
# 2  1959        NaN      Edward Hickox  Contributor
# 3  1959  mikange01       George Mikan       Player
# 4  1959        NaN      Hank Luisetti       Player
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Master

# %%
master = pd.read_csv("RawData/BasketballDB-20130121/basketball_master.csv")
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5062 entries, 0 to 5061
# Data columns (total 26 columns):
# bioID            5062 non-null object
# useFirst         4231 non-null object
# firstName        5038 non-null object
# middleName       3246 non-null object
# lastName         5062 non-null object
# nameGiven        10 non-null object
# fullGivenName    27 non-null object
# nameSuffix       324 non-null object
# nameNick         2708 non-null object
# pos              4880 non-null object
# firstseason      5047 non-null float64
# lastseason       5047 non-null float64
# height           5049 non-null float64
# weight           5048 non-null float64
# college          4884 non-null object
# collegeOther     854 non-null object
# birthDate        5051 non-null object
# birthCity        3888 non-null object
# birthState       3608 non-null object
# birthCountry     3902 non-null object
# highSchool       4289 non-null object
# hsCity           4297 non-null object
# ...

# %%
master.head()
# Out:
#        bioID useFirst  firstName  middleName      lastName  nameGiven  \
# 0      bioID    bioID  firstName  middleName      lastName  nameGiven
# 1  abdelal01     Alaa       Alaa         NaN     Abdelnaby        NaN
# 2  abdulka01   Kareem     Kareem         NaN  Abdul-Jabbar        NaN
# 3  abdulma01    Mahdi      Mahdi         NaN  Abdul-Rahman        NaN
# 4  abdulma02  Mahmoud    Mahmoud         NaN    Abdul-Rauf        NaN
#
#                    fullGivenName  nameSuffix  nameNick  pos  firstseason  \
# 0                  fullGivenName  nameSuffix  nameNick  pos            0
# 1                            NaN         NaN       NaN  F-C            0
# 2  Ferdinand Lewis Alcindor, Jr.         NaN  Lew, Cap    C            0
# 3    Walter Raphael Hazzard, Jr.         NaN      Walt    G            0
# 4            Chris Wayne Jackson         NaN       NaN    G            0
#
#    lastseason  height  weight          college       collegeOther   birthDate  \
# ...

# %% [markdown]
# ## Series Post

# %%
series_post = pd.read_csv("RawData/BasketballDB-20130121/basketball_series_post.csv")
series_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775 entries, 0 to 774
# Data columns (total 9 columns):
# year          775 non-null int64
# round         775 non-null object
# series        775 non-null object
# tmIDWinner    775 non-null object
# lgIDWinner    775 non-null object
# tmIDLoser     769 non-null object
# lgIDLoser     775 non-null object
# W             775 non-null int64
# L             775 non-null int64
# dtypes: int64(3), object(6)

# %%
series_post.head()
# Out:
#    year round series tmIDWinner lgIDWinner tmIDLoser lgIDLoser  W  L
# 0  1946     F      O        PHW        NBA       CHS       NBA  4  1
# 1  1946    QF      M        NYK        NBA       CLR       NBA  2  1
# 2  1946    QF      M        PHW        NBA       STB       NBA  2  1
# 3  1946    SF      N        PHW        NBA       NYK       NBA  2  0
# 4  1946    SF      N        CHS        NBA       WSC       NBA  4  2
#
# [5 rows x 9 columns]

# %% [markdown]
# ## All Star Players

# %%
all_star_players = pd.read_csv("RawData/BasketballDB-20130121/basketball_player_allstar.csv")
all_star_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1609 entries, 0 to 1608
# Data columns (total 23 columns):
# player_id          1609 non-null object
# last_name          1609 non-null object
# first_name         1609 non-null object
# season_id          1609 non-null int64
# conference         1609 non-null object
# league_id          1609 non-null object
# games_played       1609 non-null int64
# minutes            1609 non-null int64
# points             1562 non-null float64
# o_rebounds         493 non-null float64
# d_rebounds         493 non-null float64
# rebounds           1562 non-null float64
# assists            1562 non-null float64
# steals             398 non-null float64
# blocks             398 non-null float64
# turnovers          493 non-null float64
# personal_fouls     540 non-null float64
# fg_attempted       1562 non-null float64
# fg_made            1562 non-null float64
# ft_attempted       1562 non-null float64
# ft_made            1562 non-null float64
# ...

# %%
all_star_players.head()
# Out:
#    player_id     last_name first_name  season_id conference league_id  \
# 0  abdulka01  Abdul-Jabbar     Kareem       1978       West       NBA
# 1  abdulka01  Abdul-Jabbar     Kareem       1969       East       NBA
# 2  abdulka01  Abdul-Jabbar     Kareem       1988       West       NBA
# 3  abdulka01  Abdul-Jabbar     Kareem       1987       West       NBA
# 4  abdulka01  Abdul-Jabbar     Kareem       1986       West       NBA
#
#    games_played  minutes  points  o_rebounds  d_rebounds  rebounds  assists  \
# 0             1       28      11         NaN         NaN         8        3
# 1             1       18      10         NaN         NaN        11        4
# 2             1       13       4         NaN         NaN         3        0
# 3             1       14      10         NaN         NaN         4        0
# 4             1       27      10         NaN         NaN         8        3
#
#    steals  blocks  turnovers  personal_fouls  fg_attempted  fg_made  \
# ...

# %% [markdown]
# ## Coach Awards

# %%
coach_awards = pd.read_csv("RawData/BasketballDB-20130121/basketball_awards_coaches.csv")
coach_awards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 5 columns):
# year       61 non-null int64
# coachID    61 non-null object
# award      61 non-null object
# lgID       61 non-null object
# note       4 non-null object
# dtypes: int64(1), object(4)

# %%
coach_awards.head()
# Out:
#    year    coachID                  award lgID note
# 0  1962  gallaha01  NBA Coach of the Year  NBA  NaN
# 1  1963  hannual01  NBA Coach of the Year  NBA  NaN
# 2  1964  auerbre01  NBA Coach of the Year  NBA  NaN
# 3  1965  schaydo01  NBA Coach of the Year  NBA  NaN
# 4  1966   kerrjo01  NBA Coach of the Year  NBA  NaN
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Player Awards

# %%
player_awards = pd.read_csv("RawData/BasketballDB-20130121/basketball_awards_players.csv")
player_awards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1719 entries, 0 to 1718
# Data columns (total 6 columns):
# playerID    1719 non-null object
# award       1719 non-null object
# year        1719 non-null int64
# lgID        1719 non-null object
# note        37 non-null object
# pos         833 non-null object
# dtypes: int64(1), object(5)

# %%
player_awards.head()
# Out:
#     playerID               award  year lgID note  pos
# 0  feeribo01  All-NBA First Team  1946  NBA  NaN  NaN
# 1  fulksjo01  All-NBA First Team  1946  NBA  NaN  NaN
# 2  mckinho01  All-NBA First Team  1946  NBA  NaN  NaN
# 3  miasest01  All-NBA First Team  1946  NBA  NaN  NaN
# 4  zasloma01  All-NBA First Team  1946  NBA  NaN  NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Check all columns in all DataFrames

# %%
dfs = [teams, drafts, players, abbrev, hof, master, all_star_players, series_post, coaches, coach_awards, player_awards]

# %%
from itertools import chain
from collections import Counter

# %%
column_counter = Counter(chain.from_iterable([df.columns for df in dfs]))

# %%
column_counter.most_common()
# Out:
# [('year', 7),
#  ('lgID', 6),
#  ('tmID', 4),
#  ('playerID', 3),
#  ('note', 3),
#  ('coachID', 2),
#  ('award', 2),
#  ('rebounds', 2),
#  ('name', 2),
#  ('lost', 2),
#  ('blocks', 2),
#  ('won', 2),
#  ('assists', 2),
#  ('lastName', 2),
#  ('pos', 2),
#  ('firstName', 2),
#  ('minutes', 2),
#  ('stint', 2),
#  ('steals', 2),
#  ('turnovers', 2),
#  ('points', 2),
#  ('divLoss', 1),
#  ('fgAttempted', 1),
#  ('season_id', 1),
#  ('code', 1),
#  ('PostMinutes', 1),
#  ('d_asts', 1),
#  ('tmIDLoser', 1),
#  ('o_blk', 1),
#  ('o_tmRebound', 1),
#  ('o_ftm', 1),
#  ('PostTurnovers', 1),
#  ('middleName', 1),
#  ('o_fta', 1),
#  ('ft_made', 1),
#  ('fg_attempted', 1),
#  ('birthCountry', 1),
#  ('d_blk', 1),
#  ('personal_fouls', 1),
#  ('awayWon', 1),
#  ('race', 1),
#  ('GS', 1),
#  ('lgIDLoser', 1),
#  ('GP', 1),
#  ('dRebounds', 1),
#  ('d_reb', 1),
#  ('nameGiven', 1),
#  ('PostthreeAttempted', 1),
#  ('birthDate', 1),
#  ('draftRound', 1),
#  ('d_dreb', 1),
#  ('divID', 1),
# ...
